# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Breast_Cancer_Detection.csv")

# %%
data.head()
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302.0        17.99         10.38          122.80     1001.0
# 1    842517.0        20.57         17.77          132.90     1326.0
# 2  84300903.0        19.69         21.25          130.00     1203.0
# 3  84348301.0        11.42         20.38           77.58      386.1
# 4  84358402.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  diagnosis
# 0          0.4601                  0.11890        1.0
# 1          0.2750                  0.08902        1.0
# 2          0.3613                  0.08758        1.0
# 3          0.6638                  0.17300        1.0
# 4          0.2364                  0.07678        1.0
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (999, 32)

# %%
data.isnull().sum()
# Out:
# id                         430
# radius_mean                430
# texture_mean               430
# perimeter_mean             430
# area_mean                  430
# smoothness_mean            430
# compactness_mean           430
# concavity_mean             430
# concave points_mean        430
# symmetry_mean              430
# fractal_dimension_mean     430
# radius_se                  430
# texture_se                 430
# perimeter_se               430
# area_se                    430
# smoothness_se              430
# compactness_se             430
# concavity_se               430
# concave points_se          430
# symmetry_se                430
# fractal_dimension_se       430
# radius_worst               430
# texture_worst              430
# perimeter_worst            430
# area_worst                 430
# smoothness_worst           430
# compactness_worst          430
# concavity_worst            430
# concave points_worst       430
# symmetry_worst             430
# fractal_dimension_worst    430
# diagnosis                  430
# dtype: int64

# %%
data=data.dropna()
data.shape
# Out:
# (569, 32)

# %%
data
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  diagnosis
# 0                  0.2654          0.4601                  0.11890        1.0
# 1                  0.1860          0.2750                  0.08902        1.0
# 2                  0.2430          0.3613                  0.08758        1.0
# 3                  0.2575          0.6638                  0.17300        1.0
# 4                  0.1625          0.2364                  0.07678        1.0
# ..                    ...             ...                      ...        ...
# 564                0.2216          0.2060                  0.07115        1.0
# 565                0.1628          0.2572                  0.06637        1.0
# 566                0.1418          0.2218                  0.07820        1.0
# 567                0.2650          0.4087                  0.12400        1.0
# 568                0.0000          0.2871                  0.07039        0.0
#
# [569 rows x 32 columns]

# %%
X=data.iloc[:,:-1].values
Y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (398, 31) (171, 31)

# %%
print(Y_train.shape,Y_test.shape)
# Out:
# (398,) (171,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.23055943, -0.12348985, -0.29680142, ..., -0.84082156,
#         -0.8563616 , -0.76574773],
#        [-0.2305946 , -0.22826757, -0.65795149, ..., -0.37706655,
#         -1.3415819 , -0.41480748],
#        [-0.2302707 ,  0.14553402, -1.23056444, ..., -0.04762652,
#         -0.08997059,  0.4882635 ],
#        ...,
#        [-0.16718429,  0.03226081, -0.55578404, ..., -1.26179013,
#         -0.6828391 , -1.27672587],
#        [-0.23025553, -0.05552593,  0.10949242, ...,  1.07924018,
#          0.4755842 ,  1.25530227],
#        [-0.23061433, -0.56525537,  0.32333128, ..., -0.61952313,
#         -0.30366032, -0.84348042]])

# %%
X_test
# Out:
# array([[-0.25675458, -0.44180872, -0.22163893, ..., -0.21335976,
#          0.11865301,  0.13539217],
#        [-0.25033543,  1.40986153,  0.38303372, ...,  0.89553559,
#         -0.64528246, -0.98835798],
#        [-0.25741393,  0.41390906, -0.02528766, ...,  0.50154822,
#         -0.17339144, -0.24473803],
#        ...,
#        [-0.25022701, -1.17618057, -0.34212721, ..., -0.24774412,
#         -0.54133444,  1.62783221],
#        [-0.25672485, -0.05544785,  1.09257579, ...,  0.51157699,
#          1.16968301,  1.73703514],
#        [-0.25012704, -0.32160756, -1.22347664, ...,  0.56888424,
#         -0.50008522,  1.71103444]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
X_tain_pred=classifier.predict(X_train)
accuracy=accuracy_score(Y_train,X_tain_pred)
accuracy
# Out:
# 0.9874371859296482

# %%
X_pred=classifier.predict(X_test)
accuracy=accuracy_score(Y_test,X_pred)
accuracy
# Out:
# 0.9824561403508771
